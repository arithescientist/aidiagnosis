# %%
# importing neccessary libraries
from glob import glob
import numpy as np
import pandas as pd
import random
from skimage.io import imread
import os, shutil
import tensorflow as tf
import keras
from tensorflow.keras.layers import Input
from collections import Counter
from scikitplot.metrics import plot_roc
from sklearn import metrics
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
from PIL import Image
import seaborn as sns
from sklearn.preprocessing import LabelBinarizer
import scikitplot
import sklearn
import cv2
from tensorflow.keras.utils import to_categorical
from sklearn.linear_model import Ridge
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.decomposition import PCA
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import VotingClassifier,AdaBoostClassifier,RandomForestClassifier,ExtraTreesClassifier,GradientBoostingClassifier,GradientBoostingRegressor
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn.feature_selection import VarianceThreshold
from sklearn import datasets 
from tensorflow.keras.applications import VGG16
from tensorflow.keras.layers import AveragePooling2D
from sklearn import tree
from sklearn.naive_bayes import GaussianNB 
from sklearn.model_selection import validation_curve
import imblearn
from sklearn.decomposition import TruncatedSVD
from sklearn.metrics import precision_score, precision_recall_curve, average_precision_score, recall_score, accuracy_score, f1_score, make_scorer, classification_report, auc, roc_curve, roc_auc_score, confusion_matrix
from imblearn.pipeline import make_pipeline as make_pipeline_imb
from imblearn.under_sampling import NearMiss
from imblearn.metrics import classification_report_imbalanced
from imblearn.over_sampling import SMOTE
from keras.applications import MobileNet, DenseNet201, DenseNet121, VGG19, InceptionV3, MobileNetV2, Xception, ResNet152V2, NASNetLarge
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Activation, Flatten, GlobalAveragePooling2D
from keras.layers import Conv2D, MaxPool2D, ZeroPadding2D
from keras.layers.normalization import BatchNormalization
from keras.preprocessing.image import ImageDataGenerator
from keras.applications.resnet50 import preprocess_input, decode_predictions
from tensorflow.python.keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img
from keras.optimizers import Adam, SGD
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
# %matplotlib inline
# Out:
# Bad key "text.kerning_factor" on line 4 in
# C:\Users\jrizz_000\anaconda3\anaconda3\envs\learn-env\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution

# %% [markdown]
# # Data Processessing

# %%
# counting the amount of x rays images
len_normal_train = len([iq for iq in os.scandir('xrays/covidvsnormal/train/normal')])
len_normal_test = len([iq for iq in os.scandir('xrays/covidvsnormal/test/normal')])
len_normal_val = len([iq for iq in os.scandir('xrays/covidvsnormal/val/normal')])

len_covid_train = len([iq for iq in os.scandir('xrays/covidvsnormal/train/covid')])
len_covid_val = len([iq for iq in os.scandir('xrays/covidvsnormal/val/covid')])
len_covid_test = len([iq for iq in os.scandir('xrays/covidvsnormal/test/covid')])


len_train_total = len_normal_train + len_covid_train
len_val_total = len_covid_val + len_normal_val
len_test_total = len_normal_test + len_covid_test

print("Total")
print("---------------------")
print ("normal: ", len_normal_train)
print ("normal no val: ", len_normal_val)
print ("normal no test: ", len_normal_test)
print("---------------------")
print ("covid no train: ", len_covid_train)
print ("covid no val: ", len_covid_val)
print ("covid no test: ", len_covid_test)
print()
print("Total")
print("---------------------")
print("total train: ", len_train_total)
print("total val: ", len_val_total)
print("total test: ", len_test_total)
# Out:
# Total
# ---------------------
# normal:  863
# normal no val:  206
# normal no test:  272
# ---------------------
# covid no train:  666
# covid no val:  167
# covid no test:  39
#
# Total
# ---------------------
# total train:  1529
# total val:  373
# total test:  311

# %%
# extracting the images
DIR_NAME = 'xrays/covidvsnormal/'

imagePaths=[]
for dirname, _, filenames in os.walk(DIR_NAME):
    for filename in filenames:
        imagePaths.append(os.path.join(dirname, filename))

# %%
# verifying if the images have been extracted
imagePaths
# Out:
# ['xrays/covidvsnormal/test\\covid\\COVID-19(152).png',
#  'xrays/covidvsnormal/test\\covid\\COVID-19(153).png',
#  'xrays/covidvsnormal/test\\covid\\COVID-19(154).png',
#  'xrays/covidvsnormal/test\\covid\\COVID-19(155).png',
#  'xrays/covidvsnormal/test\\covid\\COVID-19(156).png',
#  'xrays/covidvsnormal/test\\covid\\COVID-19(157).png',
#  'xrays/covidvsnormal/test\\covid\\COVID-19(158).png',
#  'xrays/covidvsnormal/test\\covid\\COVID-19(159).png',
#  'xrays/covidvsnormal/test\\covid\\COVID-19(160).png',
#  'xrays/covidvsnormal/test\\covid\\COVID-19(161).png',
#  'xrays/covidvsnormal/test\\covid\\COVID-19(162).png',
#  'xrays/covidvsnormal/test\\covid\\COVID-19(163).png',
#  'xrays/covidvsnormal/test\\covid\\COVID-19(164).png',
#  'xrays/covidvsnormal/test\\covid\\COVID-19(165).png',
#  'xrays/covidvsnormal/test\\covid\\COVID-19(166).png',
#  'xrays/covidvsnormal/test\\covid\\COVID-19(167).png',
#  'xrays/covidvsnormal/test\\covid\\COVID-19(168).png',
#  'xrays/covidvsnormal/test\\covid\\COVID-19(169).png',
#  'xrays/covidvsnormal/test\\covid\\COVID-19(170).png',
#  'xrays/covidvsnormal/test\\covid\\COVID-19(171).png',
#  'xrays/covidvsnormal/test\\covid\\COVID-19(172).png',
#  'xrays/covidvsnormal/test\\covid\\COVID-19(173).png',
#  'xrays/covidvsnormal/test\\covid\\COVID-19(174).png',
#  'xrays/covidvsnormal/test\\covid\\COVID-19(175).png',
#  'xrays/covidvsnormal/test\\covid\\COVID-19(176).png',
#  'xrays/covidvsnormal/test\\covid\\COVID-19(177).png',
#  'xrays/covidvsnormal/test\\covid\\COVID-19(178).png',
#  'xrays/covidvsnormal/test\\covid\\COVID-19(179).png',
#  'xrays/covidvsnormal/test\\covid\\COVID-19(180).png',
#  'xrays/covidvsnormal/test\\covid\\COVID-19(181).png',
#  'xrays/covidvsnormal/test\\covid\\COVID-19(182).png',
#  'xrays/covidvsnormal/test\\covid\\COVID-19(183).png',
#  'xrays/covidvsnormal/test\\covid\\COVID-19(184).png',
#  'xrays/covidvsnormal/test\\covid\\COVID-19(185).png',
#  'xrays/covidvsnormal/test\\covid\\COVID-19(186).png',
#  'xrays/covidvsnormal/test\\covid\\COVID-19(187).png',
#  'xrays/covidvsnormal/test\\covid\\COVID-19(188).png',
#  'xrays/covidvsnormal/test\\covid\\COVID-19(189).png',
#  'xrays/covidvsnormal/test\\covid\\COVID-19(190).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (432).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (433).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (433)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (434).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (434)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (435).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (435)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (436).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (436)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (437).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (437)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (438).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (438)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (439).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (439)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (440).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (440)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (441).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (441)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (442).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (442)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (443).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (443)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (444).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (444)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (445).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (445)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (446).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (446)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (447).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (447)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (448).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (448)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (449).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (449)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (450).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (450)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (451).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (451)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (452).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (452)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (453).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (453)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (454).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (454)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (455).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (455)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (456).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (456)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (457).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (457)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (458).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (458)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (459).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (459)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (460).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (460)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (461).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (461)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (462).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (462)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (463).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (463)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (464).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (464)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (465).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (465)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (466).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (466)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (467).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (467)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (468).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (468)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (469).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (469)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (470).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (470)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (471).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (471)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (472).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (472)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (473).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (473)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (474).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (474)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (475).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (475)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (476).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (476)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (477).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (477)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (478).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (478)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (479).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (479)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (480).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (480)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (481).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (481)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (482).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (482)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (483).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (483)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (484).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (484)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (485).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (485)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (486).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (486)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (487).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (487)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (488).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (488)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (489).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (489)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (490).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (490)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (491).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (491)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (492).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (492)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (493).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (493)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (494).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (494)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (495).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (495)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (496).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (496)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (497).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (497)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (498).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (498)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (499).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (499)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (500).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (500)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (501).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (501)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (502).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (502)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (503).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (503)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (504).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (504)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (505).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (505)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (506).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (506)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (507).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (507)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (508).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (508)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (509).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (509)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (510).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (510)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (511).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (511)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (512).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (512)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (513).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (513)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (514).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (514)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (515).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (515)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (516).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (516)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (517).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (517)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (518).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (518)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (519).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (519)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (520).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (520)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (521).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (521)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (522).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (522)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (523).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (523)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (524).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (524)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (525).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (525)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (526).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (526)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (527).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (527)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (528).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (528)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (529).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (529)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (530).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (530)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (531).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (531)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (532).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (532)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (533).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (533)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (534).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (534)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (535).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (535)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (536).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (536)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (537).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (537)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (538).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (538)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (539).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (539)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (540).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (540)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (541).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (541)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (542).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (542)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (543).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (543)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (544).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (544)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (545).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (545)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (546).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (546)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (547).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (547)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (548).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (548)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (549).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (549)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (550).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (550)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (551).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (551)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (552).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (552)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (553).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (553)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (554).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (554)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (555).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (555)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (556).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (556)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (557).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (557)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (558).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (558)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (559).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (559)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (560).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (560)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (561).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (561)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (562).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (562)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (563).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (563)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (564).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (564)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (565).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (565)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (566).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (566)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (567).png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (567)_1.png',
#  'xrays/covidvsnormal/test\\normal\\NORMAL (568).png',
#  'xrays/covidvsnormal/train\\covid\\01E392EE-69F9-4E33-BFCE-E5C968654078.jpeg',
#  'xrays/covidvsnormal/train\\covid\\03BF7561-A9BA-4C3C-B8A0-D3E585F73F3C.jpeg',
#  'xrays/covidvsnormal/train\\covid\\0a7faa2a.jpg',
#  'xrays/covidvsnormal/train\\covid\\1-s2.0-S0140673620303706-fx1_lrg.jpg',
#  'xrays/covidvsnormal/train\\covid\\1-s2.0-S1684118220300608-main.pdf-001.jpg',
#  'xrays/covidvsnormal/train\\covid\\1-s2.0-S1684118220300682-main.pdf-002-a2.png',
#  'xrays/covidvsnormal/train\\covid\\1-s2.0-S1684118220300682-main.pdf-003-b1.png',
#  'xrays/covidvsnormal/train\\covid\\1-s2.0-S1684118220300682-main.pdf-003-b2.png',
#  'xrays/covidvsnormal/train\\covid\\1.CXRCTThoraximagesofCOVID-19fromSingapore.pdf-000-fig1b.png',
#  'xrays/covidvsnormal/train\\covid\\1.CXRCTThoraximagesofCOVID-19fromSingapore.pdf-001-fig2a.png',
#  'xrays/covidvsnormal/train\\covid\\1.CXRCTThoraximagesofCOVID-19fromSingapore.pdf-002-fig3b.png',
#  'xrays/covidvsnormal/train\\covid\\10.1016-slash-j.crad.2020.04.002-a.png',
#  'xrays/covidvsnormal/train\\covid\\10.1016-slash-j.crad.2020.04.002-b.png',
#  'xrays/covidvsnormal/train\\covid\\12941_2020_358_Fig1_HTML.jpg',
#  'xrays/covidvsnormal/train\\covid\\1312A392-67A3-4EBF-9319-810CF6DA5EF6.jpeg',
#  'xrays/covidvsnormal/train\\covid\\16654_1_1.png',
#  'xrays/covidvsnormal/train\\covid\\16654_2_1.jpg',
#  'xrays/covidvsnormal/train\\covid\\16654_4_1.jpg',
#  'xrays/covidvsnormal/train\\covid\\16660_1_1.jpg',
#  'xrays/covidvsnormal/train\\covid\\16660_2_1.jpg',
#  'xrays/covidvsnormal/train\\covid\\16660_4_1.jpg',
#  'xrays/covidvsnormal/train\\covid\\16663_1_1.jpg',
#  'xrays/covidvsnormal/train\\covid\\16664_1_1.jpg',
#  'xrays/covidvsnormal/train\\covid\\16669_1_1.jpeg',
#  'xrays/covidvsnormal/train\\covid\\16672_1_1.jpg',
#  'xrays/covidvsnormal/train\\covid\\16708_1_1.jpg',
#  'xrays/covidvsnormal/train\\covid\\16745_5_1.png',
#  'xrays/covidvsnormal/train\\covid\\19abe1f3.jpg',
#  'xrays/covidvsnormal/train\\covid\\1B734A89-A1BF-49A8-A1D3-66FAFA4FAC5D.jpeg',
#  'xrays/covidvsnormal/train\\covid\\23E99E2E-447C-46E5-8EB2-D35D12473C39.png',
#  'xrays/covidvsnormal/train\\covid\\2C26F453-AF3B-4517-BB9E-802CF2179543.jpeg',
#  'xrays/covidvsnormal/train\\covid\\2cd63b76.jpg',
#  'xrays/covidvsnormal/train\\covid\\31BA3780-2323-493F-8AED-62081B9C383B.jpeg',
#  'xrays/covidvsnormal/train\\covid\\353889E0-A1E8-4F9E-A0B8-F24F36BCFBFB.jpeg',
#  'xrays/covidvsnormal/train\\covid\\3b46de94.jpg',
#  'xrays/covidvsnormal/train\\covid\\41182_2020_203_Fig3_HTML.jpg',
#  'xrays/covidvsnormal/train\\covid\\41182_2020_203_Fig4_HTML.jpg',
#  'xrays/covidvsnormal/train\\covid\\41182_2020_203_Fig5_HTML.jpg',
#  'xrays/covidvsnormal/train\\covid\\41379_2020_536_Fig2_HTML-c1.png',
#  'xrays/covidvsnormal/train\\covid\\41591_2020_819_Fig1_HTML.webp-day10.png',
#  'xrays/covidvsnormal/train\\covid\\41591_2020_819_Fig1_HTML.webp-day5.png',
#  'xrays/covidvsnormal/train\\covid\\48c4542c.jpg',
#  'xrays/covidvsnormal/train\\covid\\4d98e1de.jpg',
#  'xrays/covidvsnormal/train\\covid\\4e43e48d52c9e2d4c6c1fb9bc1544f_jumbo.jpeg',
#  'xrays/covidvsnormal/train\\covid\\53EC07C9-5CC6-4BE4-9B6F-D7B0D72AAA7E.jpeg',
#  'xrays/covidvsnormal/train\\covid\\58cb9263f16e94305c730685358e4e_jumbo.jpeg',
#  'xrays/covidvsnormal/train\\covid\\6b3bdbc31f65230b8cdcc3cef5f8ba8a-40ac-0.jpg',
#  'xrays/covidvsnormal/train\\covid\\6b44464d-73a7-4cf3-bbb6-ffe7168300e3.annot.original.jpeg',
#  'xrays/covidvsnormal/train\\covid\\6CB4EFC6-68FA-4CD5-940C-BEFA8DAFE9A7.jpeg',
#  'xrays/covidvsnormal/train\\covid\\7-fatal-covid19.jpg',
#  'xrays/covidvsnormal/train\\covid\\7AF6C1AF-D249-4BD2-8C26-449304105D03.jpeg',
#  'xrays/covidvsnormal/train\\covid\\7afaaccc.jpg',
#  'xrays/covidvsnormal/train\\covid\\7C69C012-7479-493F-8722-ABC29C60A2DD.jpeg',
#  'xrays/covidvsnormal/train\\covid\\80446565-E090-4187-A031-9D3CEAA586C8.jpeg',
#  'xrays/covidvsnormal/train\\covid\\85E52EB3-56E9-4D67-82DA-DEA247C82886.jpeg',
#  'xrays/covidvsnormal/train\\covid\\88de9d8c39e946abd495b37cd07d89e5-6531-0.jpg',
#  'xrays/covidvsnormal/train\\covid\\8da14fff.jpg',
#  'xrays/covidvsnormal/train\\covid\\8FDE8DBA-CFBD-4B4C-B1A4-6F36A93B7E87.jpeg',
#  'xrays/covidvsnormal/train\\covid\\93FE0BB1-022D-4F24-9727-987A07975FFB.jpeg',
#  'xrays/covidvsnormal/train\\covid\\9fdd3c3032296fd04d2cad5d9070d4_jumbo.jpeg',
#  'xrays/covidvsnormal/train\\covid\\ac4f6e4e.jpg',
#  'xrays/covidvsnormal/train\\covid\\all14238-fig-0001-m-b.jpg',
#  'xrays/covidvsnormal/train\\covid\\all14238-fig-0001-m-c.jpg',
#  'xrays/covidvsnormal/train\\covid\\AR-1.jpg',
#  'xrays/covidvsnormal/train\\covid\\AR-2.jpg',
#  'xrays/covidvsnormal/train\\covid\\auntminnie-a-2020_01_28_23_51_6665_2020_01_28_Vietnam_coronavirus.jpeg',
#  'xrays/covidvsnormal/train\\covid\\auntminnie-c-2020_01_28_23_51_6665_2020_01_28_Vietnam_coronavirus.jpeg',
#  'xrays/covidvsnormal/train\\covid\\B2D20576-00B7-4519-A415-72DE29C90C34.jpeg',
#  'xrays/covidvsnormal/train\\covid\\b9673e89.jpg',
#  'xrays/covidvsnormal/train\\covid\\bd10d5e2.jpg',
#  'xrays/covidvsnormal/train\\covid\\BMJ-37-163-g1.jpg',
#  'xrays/covidvsnormal/train\\covid\\c0f74558.jpg',
#  'xrays/covidvsnormal/train\\covid\\CD50BA96-6982-4C80-AE7B-5F67ACDBFA56.jpeg',
#  'xrays/covidvsnormal/train\\covid\\ciaa199.pdf-001-b.png',
#  'xrays/covidvsnormal/train\\covid\\ciaa199.pdf-001-c.png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (1).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (10).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (109).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (11).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (112).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (113).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (114).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (115).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (118).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (119).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (12).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (120).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (121).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (122).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (123).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (124).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (125).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (126).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (127).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (128).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (129).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (13).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (130).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (131).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (132).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (133).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (14).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (15).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (16).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (17).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (18).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (19).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (2).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (20).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (21).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (22).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (26).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (28).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (29).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (3).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (31).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (33).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (36).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (37).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (39).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (4).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (42).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (43).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (44).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (45).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (46).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (48).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (49).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (5).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (50).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (51).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (52).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (53).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (54).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (56).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (58).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (59).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (6).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (61).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (63).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (64).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (65).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (66).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (67).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (68).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (69).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (7).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (70).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (71).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (72).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (73).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (74).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (75).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (76).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (77).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (78).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (79).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (8).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (80).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (81).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (82).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (85).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (86).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (87).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (88).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (89).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (9).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (90).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (91).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (94).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (95).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (96).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (97).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (98).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19 (99).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19(134).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19(136).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19(137).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19(138).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19(139).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19(140).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19(145).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19(146).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19(147).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19(148).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19(149).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19(150).png',
#  'xrays/covidvsnormal/train\\covid\\COVID-19(151).png',
#  'xrays/covidvsnormal/train\\covid\\covid-19-caso-70-1-PA.jpg',
#  'xrays/covidvsnormal/train\\covid\\covid-19-caso-91-1-12.png',
#  'xrays/covidvsnormal/train\\covid\\covid-19-infection-exclusive-gastrointestinal-symptoms-pa.png',
#  'xrays/covidvsnormal/train\\covid\\covid-19-pneumonia-12.jpg',
#  'xrays/covidvsnormal/train\\covid\\covid-19-pneumonia-14-PA.png',
#  'xrays/covidvsnormal/train\\covid\\covid-19-pneumonia-15-PA.jpg',
#  'xrays/covidvsnormal/train\\covid\\covid-19-pneumonia-19.jpg',
#  'xrays/covidvsnormal/train\\covid\\covid-19-pneumonia-2.jpg',
#  'xrays/covidvsnormal/train\\covid\\covid-19-pneumonia-20.jpg',
#  'xrays/covidvsnormal/train\\covid\\covid-19-pneumonia-22-day2-pa.png',
#  'xrays/covidvsnormal/train\\covid\\covid-19-pneumonia-30-PA.jpg',
#  'xrays/covidvsnormal/train\\covid\\covid-19-pneumonia-34.png',
#  'xrays/covidvsnormal/train\\covid\\covid-19-pneumonia-35-2.jpg',
#  'xrays/covidvsnormal/train\\covid\\covid-19-pneumonia-38-pa.jpg',
#  'xrays/covidvsnormal/train\\covid\\covid-19-pneumonia-44-day-0.jpeg',
#  'xrays/covidvsnormal/train\\covid\\covid-19-pneumonia-58-day-3.jpg',
#  'xrays/covidvsnormal/train\\covid\\covid-19-pneumonia-58-day-7.jpg',
#  'xrays/covidvsnormal/train\\covid\\covid-19-pneumonia-58-day-9.jpg',
#  'xrays/covidvsnormal/train\\covid\\covid-19-pneumonia-67.jpeg',
#  'xrays/covidvsnormal/train\\covid\\covid-19-pneumonia-7-PA.jpg',
#  'xrays/covidvsnormal/train\\covid\\covid-19-pneumonia-93.png',
#  'xrays/covidvsnormal/train\\covid\\covid-19-pneumonia-bilateral.jpg',
#  'xrays/covidvsnormal/train\\covid\\covid-19-pneumonia-evolution-over-a-week-1-day0-PA.jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(0).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(1).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(10).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(100).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(101).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(102).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(103).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(104).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(105).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(106).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(107).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(108).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(109).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(11).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(110).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(111).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(112).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(113).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(114).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(115).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(116).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(117).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(119).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(12).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(120).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(121).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(122).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(123).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(124).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(125).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(126).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(127).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(128).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(129).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(13).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(130).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(131).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(132).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(133).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(134).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(135).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(136).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(137).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(138).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(139).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(14).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(140).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(141).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(142).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(143).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(144).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(145).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(146).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(147).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(148).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(149).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(15).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(150).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(151).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(152).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(153).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(154).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(155).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(156).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(157).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(158).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(159).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(160).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(161).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(162).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(163).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(164).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(165).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(166).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(167).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(168).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(169).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(17).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(170).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(171).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(172).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(173).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(174).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(175).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(176).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(177).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(178).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(179).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(18).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(180).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(181).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(182).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(183).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(184).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(185).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(186).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(187).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(188).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(189).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(19).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(190).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(191).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(192).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(193).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(194).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(195).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(196).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(197).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(198).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(199).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(2).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(20).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(200).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(201).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(202).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(203).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(204).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(205).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(206).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(207).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(208).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(209).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(21).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(210).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(211).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(212).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(213).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(214).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(215).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(216).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(217).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(218).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(219).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(220).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(221).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(222).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(223).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(224).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(225).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(226).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(227).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(228).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(229).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(230).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(231).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(232).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(234).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(235).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(236).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(237).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(238).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(239).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(24).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(240).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(241).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(242).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(243).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(244).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(245).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(246).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(247).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(248).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(249).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(25).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(250).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(251).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(252).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(253).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(254).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(255).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(256).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(257).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(258).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(26).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(260).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(261).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(262).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(263).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(264).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(265).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(266).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(267).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(268).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(269).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(27).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(270).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(271).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(272).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(273).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(274).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(275).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(276).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(277).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(278).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(279).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(28).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(280).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(281).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(282).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(283).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(284).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(285).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(286).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(287).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(288).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(289).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(29).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(290).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(291).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(292).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(293).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(294).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(295).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(296).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(297).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(298).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(299).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(3).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(30).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(309).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(31).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(313).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(314).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(315).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(316).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(317).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(318).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(319).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(32).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(320).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(321).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(322).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(323).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(324).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(325).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(326).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(327).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(328).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(329).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(33).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(330).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(331).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(332).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(333).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(334).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(335).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(336).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(337).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(338).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(339).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(34).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(340).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(341).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(342).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(343).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(344).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(345).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(346).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(347).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(348).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(349).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(35).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(350).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(351).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(352).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(353).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(354).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(355).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(356).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(357).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(358).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(359).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(36).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(360).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(361).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(362).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(363).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(364).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(365).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(366).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(367).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(368).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(369).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(37).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(370).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(371).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(374).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(375).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(376).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(377).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(378).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(379).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(38).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(380).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(381).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(382).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(383).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(384).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(385).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(386).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(387).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(388).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(389).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(39).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(390).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(391).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(392).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(393).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(394).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(395).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(396).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(397).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(398).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(399).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(4).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(40).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(400).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(401).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(402).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(403).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(404).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(405).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(406).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(407).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(408).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(409).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(41).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(410).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(411).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(412).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(413).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(414).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(415).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(416).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(417).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(418).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(419).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(42).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(420).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(421).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(422).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(423).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(424).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(425).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(426).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(427).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(428).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(429).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(43).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(430).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(431).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(432).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(433).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(434).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(435).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(436).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(437).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(438).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(439).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(44).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(440).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(441).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(442).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(443).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(444).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(445).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(446).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(447).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(448).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(449).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(45).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(450).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(451).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(452).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(453).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(454).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(455).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(456).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(457).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(458).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(459).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(46).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(47).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(48).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(49).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(5).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(50).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(51).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(52).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(53).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(54).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(57).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(58).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(59).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(6).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(60).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(61).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(62).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(63).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(64).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(65).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(7).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(73).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(74).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(75).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(76).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(77).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(78).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(79).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(8).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(80).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(81).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(82).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(83).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(84).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(85).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(86).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(87).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(88).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(89).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(9).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(90).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(91).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(93).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(94).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(95).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(96).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(97).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(98).jpg',
#  'xrays/covidvsnormal/train\\covid\\COVID19(99).jpg',
#  'xrays/covidvsnormal/train\\covid\\d009d61f.jpg',
#  'xrays/covidvsnormal/train\\covid\\d9d6ca9a.jpg',
#  'xrays/covidvsnormal/train\\covid\\ec083e35.jpg',
#  'xrays/covidvsnormal/train\\covid\\F4341CE7-73C9-45C6-99C8-8567A5484B63.jpeg',
#  'xrays/covidvsnormal/train\\covid\\F63AB6CE-1968-4154-A70F-913AF154F53D.jpeg',
#  'xrays/covidvsnormal/train\\covid\\f64132c8.jpg',
#  'xrays/covidvsnormal/train\\covid\\f6575117.jpg',
#  'xrays/covidvsnormal/train\\covid\\f6d980a0.jpg',
#  'xrays/covidvsnormal/train\\covid\\f8335316.jpg',
#  'xrays/covidvsnormal/train\\covid\\FE9F9A5D-2830-46F9-851B-1FF4534959BE.jpeg',
#  'xrays/covidvsnormal/train\\covid\\fff49165-b22d-4bb4-b9d1-d5d62c52436c.annot.original.png',
#  'xrays/covidvsnormal/train\\covid\\figure1-5e71be566aa8714a04de3386-98-left.jpeg',
#  'xrays/covidvsnormal/train\\covid\\figure1-5e75d0940b71e1b702629659-98-right.jpeg',
#  'xrays/covidvsnormal/train\\covid\\kjr-21-e24-g002-l-a.jpg',
#  'xrays/covidvsnormal/train\\covid\\kjr-21-e25-g001-l-a.jpg',
#  'xrays/covidvsnormal/train\\covid\\lancet-case2a.jpg',
#  'xrays/covidvsnormal/train\\covid\\lancet-case2b.jpg',
#  'xrays/covidvsnormal/train\\covid\\nCoV-radiol.2020200269.fig1-day7.jpeg',
#  'xrays/covidvsnormal/train\\covid\\nejmc2001573_f1a.jpeg',
#  'xrays/covidvsnormal/train\\covid\\nejmc2001573_f1b.jpeg',
#  'xrays/covidvsnormal/train\\covid\\nejmoa2001191_f3-PA.jpeg',
#  'xrays/covidvsnormal/train\\covid\\nejmoa2001191_f4.jpeg',
#  'xrays/covidvsnormal/train\\covid\\ryct.2020200034.fig2.jpeg',
#  'xrays/covidvsnormal/train\\covid\\ryct.2020200034.fig5-day0.jpeg',
#  'xrays/covidvsnormal/train\\covid\\ryct.2020200034.fig5-day4.jpeg',
#  'xrays/covidvsnormal/train\\normal\\NORMAL (1).png',
#  'xrays/covidvsnormal/train\\normal\\NORMAL (1)_1.png',
#  'xrays/covidvsnormal/train\\normal\\NORMAL (10).png',
#  'xrays/covidvsnormal/train\\normal\\NORMAL (10)_1.png',
#  'xrays/covidvsnormal/train\\normal\\NORMAL (100).png',
#  'xrays/covidvsnormal/train\\normal\\NORMAL (100)_1.png',
#  'xrays/covidvsnormal/train\\normal\\NORMAL (101).png',
#  'xrays/covidvsnormal/train\\normal\\NORMAL (101)_1.png',
#  'xrays/covidvsnormal/train\\normal\\NORMAL (102).png',
#  'xrays/covidvsnormal/train\\normal\\NORMAL (102)_1.png',
#  'xrays/covidvsnormal/train\\normal\\NORMAL (103).png',
#  'xrays/covidvsnormal/train\\normal\\NORMAL (103)_1.png',
#  'xrays/covidvsnormal/train\\normal\\NORMAL (104).png',
#  'xrays/covidvsnormal/train\\normal\\NORMAL (104)_1.png',
#  'xrays/covidvsnormal/train\\normal\\NORMAL (105).png',
#  'xrays/covidvsnormal/train\\normal\\NORMAL (105)_1.png',
#  'xrays/covidvsnormal/train\\normal\\NORMAL (106).png',
#  'xrays/covidvsnormal/train\\normal\\NORMAL (106)_1.png',
#  'xrays/covidvsnormal/train\\normal\\NORMAL (107).png',
#  'xrays/covidvsnormal/train\\normal\\NORMAL (107)_1.png',
#  'xrays/covidvsnormal/train\\normal\\NORMAL (108).png',
#  'xrays/covidvsnormal/train\\normal\\NORMAL (108)_1.png',
#  'xrays/covidvsnormal/train\\normal\\NORMAL (109).png',
#  ...]

# %%
# assigining the labels to the images
data = []
labels = []
# loop over the image paths
for imagePath in imagePaths:
    # extract the class label from the filename
    label = imagePath.split(os.path.sep)[-2]
    # load the image, swap color channels, and resize it to be a fixed
    # 224x224 pixels while ignoring aspect ratio
    image = cv2.imread(imagePath)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image = cv2.resize(image, (64, 64))
    # update the data and labels lists, respectively
    data.append(image)
    labels.append(label)
# convert the data and labels to NumPy arrays while scaling the pixel
# intensities to the range [0, 1]
data = np.array(data) / 255.0
labels = np.array(labels)

# %%
# verifying the shape
data.shape
# Out:
# (2213, 64, 64, 3)

# %%
# verifying the labels
labels
# Out:
# array(['covid', 'covid', 'covid', ..., 'normal', 'normal', 'normal'],
#       dtype='<U6')

# %%
# perform one-hot encoding on the labels
lb = LabelBinarizer()
labels = lb.fit_transform(labels)
labels = to_categorical(labels)
# partition the data into training and testing splits using 80% of
# the data for training and the remaining 20% for testing
(x_train, x_test, y_train, y_test) = train_test_split(data, labels,
    test_size=0.20, stratify=labels, random_state=42)

# %% [markdown]
# # Data Augmentation

# %%
# Data Augmentation
def process_data(x_train,y_train, x_test,y_test, batch_size):
    #to prevent overfitting
    train_datagen = ImageDataGenerator(shear_range=0.2,
                                   rotation_range=20,
                                   width_shift_range=0.2,
                                   height_shift_range=0.2,
                                   horizontal_flip=True,
                                   vertical_flip=False,
                                   zoom_range=0.2)


    validation_datagen = ImageDataGenerator()

    train_generator = train_datagen.flow(x_train,y_train,
                                                        batch_size=batch_size)

    validation_generator = validation_datagen.flow(x_test,y_test,
                                                  batch_size=batch_size)



    return train_generator, validation_generator

# %% [markdown]
# # Transfer Learning

# %%
# adding top layer
def addTopModel(bottom_model, num_classes):
    top_model = bottom_model.output
    #top_model = AveragePooling2D(pool_size=(2, 2))(top_model)
    top_model = Flatten(name="flatten")(top_model)
    top_model = Dense(512, activation="relu")(top_model)
    top_model = Dropout(0.5)(top_model)
    top_model = Dense(2, activation='sigmoid')(top_model)
    
    model = Model(inputs=bottom_model.input, outputs=top_model)
    
    return model

def get_model(transferleaner,x_train,y_train, x_test,y_test):
    m = transferleaner
    pred = addTopModel(m, num_classes) 


    #data augmentation
    train_generator, validation_generator = process_data(x_train,y_train,
                                                     x_test,y_test, batch_size)

    model.summary()

    checkpoint = ModelCheckpoint(data_dir+'modelcnd'+'.h5',
                                 monitor='val_loss',
                                 mode="min",
                                 save_best_only=True,
                                 verbose=1)

    earlystop = EarlyStopping(monitor='val_loss',
                              min_delta=0,
                              patience=30,
                              verbose=1,
                              restore_best_weights=True)

    learning_rate_reduction = ReduceLROnPlateau(monitor='val_loss',
                                                patience=30,
                                                verbose=1,
                                                factor=0.8,
                                                min_lr=0.0001,
                                                mode="auto",
                                                min_delta=0.0001,
                                                cooldown=5)

    callbacks = [checkpoint, earlystop, learning_rate_reduction]

    model.compile(loss=models_loss,
                  optimizer=models_opt,
                  metrics=['accuracy'])
    
    
    model.fit_generator(train_generator,
                                  steps_per_epoch=len_train_total//batch_size,
                                  epochs=epochs,
                                  callbacks=callbacks,
                                  validation_data=validation_generator,
                                  validation_steps=len_val_total//batch_size)

    history = model.fit_generator(train_generator,
                                  steps_per_epoch=len_train_total//batch_size,
                                  epochs=epochs,
                                  callbacks=callbacks,
                                  validation_data=validation_generator,
                                  validation_steps=len_val_total//batch_size)
  

    
    return model, history

# %% [markdown]
# # Confusion Matrix

# %%
# plotting confusion matrix for testing
def plot_confusion_matrix(model, x_test, y_test):
    fig, ax = plt.subplots(figsize=(8,6))

    classes = ['COVID','NORMAL']
    
    y_pred = model.predict(x_test, batch_size=batch_size)
    y_pred = np.argmax(y_pred, axis=1)
    y_test = np.argmax(y_test, axis=1) 
    
    print('Confusion Matrix')
    cm = confusion_matrix(y_test, y_pred, normalize='true')
    #cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
 
    sns.heatmap(cm,cmap='Purples',fmt='g', annot=True)
    tick_marks = [0.5,1.5]
    plt.xticks(tick_marks, classes)
    plt.yticks(tick_marks, classes)

    plt.title('Confusion Matrix - Normalized')
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    bottom, top = ax.get_ylim()
    
    ax.set_ylim(bottom + 0.5, top - 0.5)
    
    plt.show()
    
    acc = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred, average=None)
    recall = recall_score(y_test, y_pred, average=None)
    f1 = f1_score(y_test, y_pred, average=None)
    
    print("Precision Score: {}".format(precision))
    print("Recall Score: {}".format(recall))
    print("F1 Score: {}".format(f1))
    print("Accuracy Score: {}".format(acc))

    return plt.show()

# %% [markdown]
# # ROC AUC

# %%
#ROC curve
def multiclass_roc_auc_score(x_test, y_test, model, average="micro"):
    

    y_pred = model.predict(x_test, batch_size=batch_size)
    
    # Convert to Binary classes
    y_pred_bin = np.argmax(y_pred, axis=1)
    y_test_bin = np.argmax(y_test, axis=1)

    fpr, tpr, thresholds = roc_curve(y_test_bin, y_pred_bin)
    
    auc_keras = auc(fpr, tpr)
    
    print('AUC: {}'.format(auc_keras))    
    print('Log Loss: {}'.format(metrics.log_loss(y_test.argmax(axis=1), y_pred)))

        
    plt.plot(fpr, tpr,  color='darkorange', label='ROC curve (area = %0.2f)' % auc_keras)
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.0])
    plt.rcParams['font.size'] = 12
    plt.title('ROC curve for our model')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.legend(loc='best', fancybox=True)
    plt.grid(True)


    return plt.show()

# %% [markdown]
# # Model Loss

# %%
#model loss
def plot_learning_curves(r):
    plt.figure(figsize=(12,4))
    
    plt.subplot(1,2,1)
    plt.plot(r.history['loss'])
    plt.plot(r.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.grid(True)
    
    plt.subplot(1,2,2)
    plt.plot(r.history['accuracy'])
    plt.plot(r.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.grid(True)
    plt.tight_layout()
    
    return plt.show()

# %% [markdown]
# # Assigning Parameters

# %%
#parameters
data_dir = '/'
version = '-v5-'
num_classes = 2
ig_size= 64
epochs = 100
batch_size = 32

models_loss = 'binary_crossentropy'
models_opt = 'adam' #Adam(lr=0.001, decay=0.001/600) #SGD(learning_rate=0.001, momentum=0.9) #ADAM(lr=0.001)

# %% [markdown]
# # Modelling

# %%
# assiging the VGG16 model
m = VGG19(weights="imagenet", include_top=False, 
          input_tensor=Input(shape=(64, 64, 3)))


model = addTopModel(m, num_classes) 

for layer in m.layers:
    layer.trainable = False
 

    #data augmentation
train_generator, validation_generator = process_data(x_train,y_train,
                                                 x_test,y_test, batch_size)


model.summary()

checkpoint = ModelCheckpoint(data_dir+'modelcnd' + '.h5',
                             monitor='val_loss',
                             mode="min",
                             save_best_only=True,
                             verbose=1)

earlystop = EarlyStopping(monitor='val_loss',
                          min_delta=0,
                          patience=30,
                          verbose=1,
                          restore_best_weights=True)

learning_rate_reduction = ReduceLROnPlateau(monitor='val_loss',
                                            patience=30,
                                            verbose=1,
                                            factor=0.8,
                                            min_lr=0.0001,
                                            mode="auto",
                                            min_delta=0.0001,
                                            cooldown=5)

callbacks = [checkpoint, earlystop, learning_rate_reduction]

model.compile(loss=models_loss,
              optimizer=models_opt,
              metrics=['accuracy'])


model.fit(train_generator,
                             epochs=epochs,
                               callbacks=callbacks,
                              validation_data=(x_test, y_test),
                              validation_steps=len(x_test) / batch_size,
                              steps_per_epoch=len(x_train) / batch_size)

history = model.fit(train_generator,
                                epochs=epochs,
                              callbacks=callbacks,
                              validation_data=(x_test, y_test),
                              validation_steps=len(x_test) / batch_size,
                              steps_per_epoch=len(x_train) / batch_size)
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 64, 64, 3)]       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 64, 64, 64)        1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 64, 64, 64)        36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 32, 32, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 32, 32, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 32, 32, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 16, 16, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 16, 16, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 16, 16, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 16, 16, 256)       590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, 16, 16, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 8, 8, 256)         0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 8, 8, 512)         1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 4, 4, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 2, 2, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               1049088
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 1026
# =================================================================
# Total params: 21,074,498
# Trainable params: 1,050,114
# Non-trainable params: 20,024,384
# _________________________________________________________________
# Epoch 1/100
# 56/55 [==============================] - ETA: 0s - loss: 0.2750 - accuracy: 0.8887
# Epoch 00001: val_loss improved from inf to 0.14138, saving model to /modelcnd.h5
# 56/55 [==============================] - 84s 1s/step - loss: 0.2750 - accuracy: 0.8887 - val_loss: 0.1414 - val_accuracy: 0.9323 - lr: 0.0010
# Epoch 2/100
# 56/55 [==============================] - ETA: 0s - loss: 0.1348 - accuracy: 0.9452
# Epoch 00002: val_loss did not improve from 0.14138
# 56/55 [==============================] - 74s 1s/step - loss: 0.1348 - accuracy: 0.9452 - val_loss: 0.1783 - val_accuracy: 0.9097 - lr: 0.0010
# Epoch 3/100
# 56/55 [==============================] - ETA: 0s - loss: 0.1258 - accuracy: 0.9531
# Epoch 00003: val_loss did not improve from 0.14138
# 56/55 [==============================] - 74s 1s/step - loss: 0.1258 - accuracy: 0.9531 - val_loss: 0.2062 - val_accuracy: 0.9142 - lr: 0.0010
# Epoch 4/100
# 56/55 [==============================] - ETA: 0s - loss: 0.1234 - accuracy: 0.9525
# Epoch 00004: val_loss improved from 0.14138 to 0.06895, saving model to /modelcnd.h5
# 56/55 [==============================] - 81s 1s/step - loss: 0.1234 - accuracy: 0.9525 - val_loss: 0.0690 - val_accuracy: 0.9684 - lr: 0.0010
# Epoch 5/100
# 56/55 [==============================] - ETA: 0s - loss: 0.0953 - accuracy: 0.9633
# Epoch 00005: val_loss did not improve from 0.06895
# 56/55 [==============================] - 78s 1s/step - loss: 0.0953 - accuracy: 0.9633 - val_loss: 0.1407 - val_accuracy: 0.9391 - lr: 0.0010
# Epoch 6/100
# 56/55 [==============================] - ETA: 0s - loss: 0.0901 - accuracy: 0.9701
# Epoch 00006: val_loss did not improve from 0.06895
# 56/55 [==============================] - 77s 1s/step - loss: 0.0901 - accuracy: 0.9701 - val_loss: 0.2021 - val_accuracy: 0.9210 - lr: 0.0010
# Epoch 7/100
# 56/55 [==============================] - ETA: 0s - loss: 0.1123 - accuracy: 0.9582
# Epoch 00007: val_loss did not improve from 0.06895
# 56/55 [==============================] - 76s 1s/step - loss: 0.1123 - accuracy: 0.9582 - val_loss: 0.1022 - val_accuracy: 0.9526 - lr: 0.0010
# Epoch 8/100
# 56/55 [==============================] - ETA: 0s - loss: 0.0953 - accuracy: 0.9655
# Epoch 00008: val_loss did not improve from 0.06895
# 56/55 [==============================] - 73s 1s/step - loss: 0.0953 - accuracy: 0.9655 - val_loss: 0.1364 - val_accuracy: 0.9413 - lr: 0.0010
# Epoch 9/100
# 56/55 [==============================] - ETA: 0s - loss: 0.1018 - accuracy: 0.9621
# Epoch 00009: val_loss did not improve from 0.06895
# 56/55 [==============================] - 74s 1s/step - loss: 0.1018 - accuracy: 0.9621 - val_loss: 0.1216 - val_accuracy: 0.9458 - lr: 0.0010
# Epoch 10/100
# 56/55 [==============================] - ETA: 0s - loss: 0.1005 - accuracy: 0.9667
# Epoch 00010: val_loss did not improve from 0.06895
# 56/55 [==============================] - 74s 1s/step - loss: 0.1005 - accuracy: 0.9667 - val_loss: 0.0694 - val_accuracy: 0.9752 - lr: 0.0010
# Epoch 11/100
# 56/55 [==============================] - ETA: 0s - loss: 0.0917 - accuracy: 0.9689
# Epoch 00011: val_loss did not improve from 0.06895
# 56/55 [==============================] - 74s 1s/step - loss: 0.0917 - accuracy: 0.9689 - val_loss: 0.0835 - val_accuracy: 0.9684 - lr: 0.0010
# Epoch 12/100
# 56/55 [==============================] - ETA: 0s - loss: 0.0829 - accuracy: 0.9729
# Epoch 00012: val_loss improved from 0.06895 to 0.05879, saving model to /modelcnd.h5
# 56/55 [==============================] - 77s 1s/step - loss: 0.0829 - accuracy: 0.9729 - val_loss: 0.0588 - val_accuracy: 0.9774 - lr: 0.0010
# Epoch 13/100
# 56/55 [==============================] - ETA: 0s - loss: 0.0861 - accuracy: 0.9706
# Epoch 00013: val_loss did not improve from 0.05879
# 56/55 [==============================] - 73s 1s/step - loss: 0.0861 - accuracy: 0.9706 - val_loss: 0.0873 - val_accuracy: 0.9661 - lr: 0.0010
# Epoch 14/100
# 56/55 [==============================] - ETA: 0s - loss: 0.0842 - accuracy: 0.9712
# Epoch 00014: val_loss did not improve from 0.05879
# 56/55 [==============================] - 73s 1s/step - loss: 0.0842 - accuracy: 0.9712 - val_loss: 0.0820 - val_accuracy: 0.9661 - lr: 0.0010
# Epoch 15/100
# 56/55 [==============================] - ETA: 0s - loss: 0.0865 - accuracy: 0.9723
# Epoch 00015: val_loss did not improve from 0.05879
# 56/55 [==============================] - 90s 2s/step - loss: 0.0865 - accuracy: 0.9723 - val_loss: 0.0709 - val_accuracy: 0.9684 - lr: 0.0010
# Epoch 16/100
# 56/55 [==============================] - ETA: 0s - loss: 0.0871 - accuracy: 0.9661
# Epoch 00016: val_loss improved from 0.05879 to 0.04701, saving model to /modelcnd.h5
# 56/55 [==============================] - 75s 1s/step - loss: 0.0871 - accuracy: 0.9661 - val_loss: 0.0470 - val_accuracy: 0.9865 - lr: 0.0010
# Epoch 17/100
# 56/55 [==============================] - ETA: 0s - loss: 0.0742 - accuracy: 0.9706
# Epoch 00017: val_loss improved from 0.04701 to 0.04256, saving model to /modelcnd.h5
# 56/55 [==============================] - 93s 2s/step - loss: 0.0742 - accuracy: 0.9706 - val_loss: 0.0426 - val_accuracy: 0.9819 - lr: 0.0010
# Epoch 18/100
# 56/55 [==============================] - ETA: 0s - loss: 0.0969 - accuracy: 0.9638
# Epoch 00018: val_loss did not improve from 0.04256
# 56/55 [==============================] - 72s 1s/step - loss: 0.0969 - accuracy: 0.9638 - val_loss: 0.0444 - val_accuracy: 0.9819 - lr: 0.0010
# Epoch 19/100
# 56/55 [==============================] - ETA: 0s - loss: 0.0744 - accuracy: 0.9757
# Epoch 00019: val_loss did not improve from 0.04256
# 56/55 [==============================] - 81s 1s/step - loss: 0.0744 - accuracy: 0.9757 - val_loss: 0.0571 - val_accuracy: 0.9819 - lr: 0.0010
# Epoch 20/100
# 56/55 [==============================] - ETA: 0s - loss: 0.0714 - accuracy: 0.9729
# Epoch 00020: val_loss did not improve from 0.04256
# 56/55 [==============================] - 87s 2s/step - loss: 0.0714 - accuracy: 0.9729 - val_loss: 0.0578 - val_accuracy: 0.9819 - lr: 0.0010
# Epoch 21/100
# 56/55 [==============================] - ETA: 0s - loss: 0.0617 - accuracy: 0.9808
# Epoch 00021: val_loss did not improve from 0.04256
# 56/55 [==============================] - 96s 2s/step - loss: 0.0617 - accuracy: 0.9808 - val_loss: 0.0458 - val_accuracy: 0.9865 - lr: 0.0010
# Epoch 22/100
# 56/55 [==============================] - ETA: 0s - loss: 0.0623 - accuracy: 0.9757
# Epoch 00022: val_loss did not improve from 0.04256
# 56/55 [==============================] - 89s 2s/step - loss: 0.0623 - accuracy: 0.9757 - val_loss: 0.0871 - val_accuracy: 0.9684 - lr: 0.0010
# Epoch 23/100
# 56/55 [==============================] - ETA: 0s - loss: 0.0779 - accuracy: 0.9689
# Epoch 00023: val_loss did not improve from 0.04256
# 56/55 [==============================] - 84s 1s/step - loss: 0.0779 - accuracy: 0.9689 - val_loss: 0.0670 - val_accuracy: 0.9774 - lr: 0.0010
# Epoch 24/100
# 56/55 [==============================] - ETA: 0s - loss: 0.0809 - accuracy: 0.9729
# Epoch 00024: val_loss did not improve from 0.04256
# 56/55 [==============================] - 98s 2s/step - loss: 0.0809 - accuracy: 0.9729 - val_loss: 0.0579 - val_accuracy: 0.9797 - lr: 0.0010
# Epoch 25/100
# 56/55 [==============================] - ETA: -1s - loss: 0.0678 - accuracy: 0.9734
# Epoch 00025: val_loss did not improve from 0.04256
# 56/55 [==============================] - 108s 2s/step - loss: 0.0678 - accuracy: 0.9734 - val_loss: 0.0688 - val_accuracy: 0.9774 - lr: 0.0010
# Epoch 26/100
# 56/55 [==============================] - ETA: 0s - loss: 0.0679 - accuracy: 0.9763
# Epoch 00026: val_loss did not improve from 0.04256
# 56/55 [==============================] - 92s 2s/step - loss: 0.0679 - accuracy: 0.9763 - val_loss: 0.0571 - val_accuracy: 0.9774 - lr: 0.0010
# Epoch 27/100
# 56/55 [==============================] - ETA: 0s - loss: 0.0656 - accuracy: 0.9768
# Epoch 00027: val_loss did not improve from 0.04256
# 56/55 [==============================] - 94s 2s/step - loss: 0.0656 - accuracy: 0.9768 - val_loss: 0.0590 - val_accuracy: 0.9774 - lr: 0.0010
# Epoch 28/100
# 56/55 [==============================] - ETA: -1s - loss: 0.0738 - accuracy: 0.9723
# Epoch 00028: val_loss did not improve from 0.04256
# 56/55 [==============================] - 99s 2s/step - loss: 0.0738 - accuracy: 0.9723 - val_loss: 0.0712 - val_accuracy: 0.9797 - lr: 0.0010
# Epoch 29/100
# 56/55 [==============================] - ETA: 0s - loss: 0.0628 - accuracy: 0.9797
# Epoch 00029: val_loss did not improve from 0.04256
# 56/55 [==============================] - 80s 1s/step - loss: 0.0628 - accuracy: 0.9797 - val_loss: 0.1635 - val_accuracy: 0.9481 - lr: 0.0010
# Epoch 30/100
# 56/55 [==============================] - ETA: 0s - loss: 0.0721 - accuracy: 0.9689
# Epoch 00030: val_loss did not improve from 0.04256
# 56/55 [==============================] - 97s 2s/step - loss: 0.0721 - accuracy: 0.9689 - val_loss: 0.0582 - val_accuracy: 0.9819 - lr: 0.0010
# Epoch 31/100
# 56/55 [==============================] - ETA: -1s - loss: 0.0740 - accuracy: 0.9746
# Epoch 00031: val_loss improved from 0.04256 to 0.04016, saving model to /modelcnd.h5
# 56/55 [==============================] - 99s 2s/step - loss: 0.0740 - accuracy: 0.9746 - val_loss: 0.0402 - val_accuracy: 0.9819 - lr: 0.0010
# Epoch 32/100
# 56/55 [==============================] - ETA: 0s - loss: 0.0745 - accuracy: 0.9746
# Epoch 00032: val_loss did not improve from 0.04016
# 56/55 [==============================] - 86s 2s/step - loss: 0.0745 - accuracy: 0.9746 - val_loss: 0.0776 - val_accuracy: 0.9774 - lr: 0.0010
# Epoch 33/100
# 56/55 [==============================] - ETA: 0s - loss: 0.0613 - accuracy: 0.9780
# Epoch 00033: val_loss did not improve from 0.04016
# 56/55 [==============================] - 80s 1s/step - loss: 0.0613 - accuracy: 0.9780 - val_loss: 0.0910 - val_accuracy: 0.9752 - lr: 0.0010
# Epoch 34/100
# 56/55 [==============================] - ETA: 0s - loss: 0.0651 - accuracy: 0.9768
# Epoch 00034: val_loss did not improve from 0.04016
# 56/55 [==============================] - 78s 1s/step - loss: 0.0651 - accuracy: 0.9768 - val_loss: 0.0676 - val_accuracy: 0.9819 - lr: 0.0010
# Epoch 35/100
# 56/55 [==============================] - ETA: 0s - loss: 0.0715 - accuracy: 0.9768
# Epoch 00035: val_loss did not improve from 0.04016
# 56/55 [==============================] - 85s 2s/step - loss: 0.0715 - accuracy: 0.9768 - val_loss: 0.0778 - val_accuracy: 0.9797 - lr: 0.0010
# Epoch 36/100
# 56/55 [==============================] - ETA: 0s - loss: 0.0561 - accuracy: 0.9825
# Epoch 00036: val_loss did not improve from 0.04016
# 56/55 [==============================] - 81s 1s/step - loss: 0.0561 - accuracy: 0.9825 - val_loss: 0.0597 - val_accuracy: 0.9797 - lr: 0.0010
# Epoch 37/100
# 56/55 [==============================] - ETA: 0s - loss: 0.0708 - accuracy: 0.9757
# Epoch 00037: val_loss did not improve from 0.04016
# 56/55 [==============================] - 71s 1s/step - loss: 0.0708 - accuracy: 0.9757 - val_loss: 0.0743 - val_accuracy: 0.9707 - lr: 0.0010
# Epoch 38/100
# 56/55 [==============================] - ETA: 0s - loss: 0.0672 - accuracy: 0.9763
# Epoch 00038: val_loss did not improve from 0.04016
# 56/55 [==============================] - 70s 1s/step - loss: 0.0672 - accuracy: 0.9763 - val_loss: 0.0612 - val_accuracy: 0.9842 - lr: 0.0010
# Epoch 39/100
# 56/55 [==============================] - ETA: 0s - loss: 0.0698 - accuracy: 0.9797
# Epoch 00039: val_loss did not improve from 0.04016
# 56/55 [==============================] - 70s 1s/step - loss: 0.0698 - accuracy: 0.9797 - val_loss: 0.0600 - val_accuracy: 0.9819 - lr: 0.0010
# Epoch 40/100
# 56/55 [==============================] - ETA: 0s - loss: 0.0627 - accuracy: 0.9791
# Epoch 00040: val_loss did not improve from 0.04016
# 56/55 [==============================] - 86s 2s/step - loss: 0.0627 - accuracy: 0.9791 - val_loss: 0.0625 - val_accuracy: 0.9797 - lr: 0.0010
# Epoch 41/100
# 56/55 [==============================] - ETA: 0s - loss: 0.0737 - accuracy: 0.9723
# Epoch 00041: val_loss did not improve from 0.04016
# 56/55 [==============================] - 104s 2s/step - loss: 0.0737 - accuracy: 0.9723 - val_loss: 0.1225 - val_accuracy: 0.9481 - lr: 0.0010
# Epoch 42/100
# 56/55 [==============================] - ETA: 0s - loss: 0.0678 - accuracy: 0.9751
# Epoch 00042: val_loss did not improve from 0.04016
# 56/55 [==============================] - 89s 2s/step - loss: 0.0678 - accuracy: 0.9751 - val_loss: 0.1483 - val_accuracy: 0.9458 - lr: 0.0010
# Epoch 43/100
# 56/55 [==============================] - ETA: 0s - loss: 0.0593 - accuracy: 0.9785
# Epoch 00043: val_loss did not improve from 0.04016
# 56/55 [==============================] - 89s 2s/step - loss: 0.0593 - accuracy: 0.9785 - val_loss: 0.0606 - val_accuracy: 0.9797 - lr: 0.0010
# Epoch 44/100
# 56/55 [==============================] - ETA: 0s - loss: 0.0544 - accuracy: 0.9814
# Epoch 00044: val_loss did not improve from 0.04016
# 56/55 [==============================] - 83s 1s/step - loss: 0.0544 - accuracy: 0.9814 - val_loss: 0.0754 - val_accuracy: 0.9797 - lr: 0.0010
# Epoch 45/100
# 56/55 [==============================] - ETA: 0s - loss: 0.0598 - accuracy: 0.9763
# Epoch 00045: val_loss did not improve from 0.04016
# 56/55 [==============================] - 82s 1s/step - loss: 0.0598 - accuracy: 0.9763 - val_loss: 0.0580 - val_accuracy: 0.9797 - lr: 0.0010
# Epoch 46/100
# 56/55 [==============================] - ETA: 0s - loss: 0.0636 - accuracy: 0.9757
# Epoch 00046: val_loss did not improve from 0.04016
# 56/55 [==============================] - 89s 2s/step - loss: 0.0636 - accuracy: 0.9757 - val_loss: 0.0402 - val_accuracy: 0.9887 - lr: 0.0010
# Epoch 47/100
# 56/55 [==============================] - ETA: 0s - loss: 0.0724 - accuracy: 0.9678
# Epoch 00047: val_loss did not improve from 0.04016
# 56/55 [==============================] - 96s 2s/step - loss: 0.0724 - accuracy: 0.9678 - val_loss: 0.0505 - val_accuracy: 0.9797 - lr: 0.0010
# Epoch 48/100
# 56/55 [==============================] - ETA: 0s - loss: 0.0576 - accuracy: 0.9785
# Epoch 00048: val_loss did not improve from 0.04016
# 56/55 [==============================] - 76s 1s/step - loss: 0.0576 - accuracy: 0.9785 - val_loss: 0.0625 - val_accuracy: 0.9819 - lr: 0.0010
# Epoch 49/100
# 56/55 [==============================] - ETA: 0s - loss: 0.0556 - accuracy: 0.9791
# Epoch 00049: val_loss did not improve from 0.04016
# 56/55 [==============================] - 73s 1s/step - loss: 0.0556 - accuracy: 0.9791 - val_loss: 0.1173 - val_accuracy: 0.9594 - lr: 0.0010
# Epoch 50/100
# 56/55 [==============================] - ETA: 0s - loss: 0.0838 - accuracy: 0.9712
# Epoch 00050: val_loss did not improve from 0.04016
# 56/55 [==============================] - 72s 1s/step - loss: 0.0838 - accuracy: 0.9712 - val_loss: 0.0801 - val_accuracy: 0.9774 - lr: 0.0010
# Epoch 51/100
# 56/55 [==============================] - ETA: 0s - loss: 0.0571 - accuracy: 0.9763
# Epoch 00051: val_loss did not improve from 0.04016
# 56/55 [==============================] - 71s 1s/step - loss: 0.0571 - accuracy: 0.9763 - val_loss: 0.0580 - val_accuracy: 0.9797 - lr: 0.0010
# Epoch 52/100
# 56/55 [==============================] - ETA: 0s - loss: 0.0477 - accuracy: 0.9819
# Epoch 00052: val_loss did not improve from 0.04016
# 56/55 [==============================] - 84s 1s/step - loss: 0.0477 - accuracy: 0.9819 - val_loss: 0.0574 - val_accuracy: 0.9819 - lr: 0.0010
# Epoch 53/100
# 56/55 [==============================] - ETA: -1s - loss: 0.0604 - accuracy: 0.9791
# Epoch 00053: val_loss did not improve from 0.04016
# 56/55 [==============================] - 116s 2s/step - loss: 0.0604 - accuracy: 0.9791 - val_loss: 0.0453 - val_accuracy: 0.9842 - lr: 0.0010
# Epoch 54/100
# 56/55 [==============================] - ETA: 0s - loss: 0.0695 - accuracy: 0.9718
# Epoch 00054: val_loss did not improve from 0.04016
# 56/55 [==============================] - 86s 2s/step - loss: 0.0695 - accuracy: 0.9718 - val_loss: 0.0441 - val_accuracy: 0.9819 - lr: 0.0010
# Epoch 55/100
# 56/55 [==============================] - ETA: 0s - loss: 0.0715 - accuracy: 0.9729
# Epoch 00055: val_loss did not improve from 0.04016
# 56/55 [==============================] - 91s 2s/step - loss: 0.0715 - accuracy: 0.9729 - val_loss: 0.0592 - val_accuracy: 0.9797 - lr: 0.0010
# Epoch 56/100
# 56/55 [==============================] - ETA: 0s - loss: 0.0595 - accuracy: 0.9785
# Epoch 00056: val_loss did not improve from 0.04016
# 56/55 [==============================] - 73s 1s/step - loss: 0.0595 - accuracy: 0.9785 - val_loss: 0.0659 - val_accuracy: 0.9774 - lr: 0.0010
# Epoch 57/100
# 56/55 [==============================] - ETA: 0s - loss: 0.0586 - accuracy: 0.9751
# Epoch 00057: val_loss did not improve from 0.04016
# 56/55 [==============================] - 77s 1s/step - loss: 0.0586 - accuracy: 0.9751 - val_loss: 0.0611 - val_accuracy: 0.9752 - lr: 0.0010
# Epoch 58/100
# 56/55 [==============================] - ETA: -1s - loss: 0.0708 - accuracy: 0.9768
# Epoch 00058: val_loss did not improve from 0.04016
# 56/55 [==============================] - 107s 2s/step - loss: 0.0708 - accuracy: 0.9768 - val_loss: 0.0579 - val_accuracy: 0.9797 - lr: 0.0010
# Epoch 59/100
# 56/55 [==============================] - ETA: 0s - loss: 0.0681 - accuracy: 0.9751
# Epoch 00059: val_loss did not improve from 0.04016
# 56/55 [==============================] - 83s 1s/step - loss: 0.0681 - accuracy: 0.9751 - val_loss: 0.0916 - val_accuracy: 0.9594 - lr: 0.0010
# Epoch 60/100
# 56/55 [==============================] - ETA: 0s - loss: 0.0639 - accuracy: 0.9802
# Epoch 00060: val_loss did not improve from 0.04016
# 56/55 [==============================] - 98s 2s/step - loss: 0.0639 - accuracy: 0.9802 - val_loss: 0.1164 - val_accuracy: 0.9571 - lr: 0.0010
# Epoch 61/100
# 56/55 [==============================] - ETA: 0s - loss: 0.0478 - accuracy: 0.9819
# Epoch 00061: val_loss did not improve from 0.04016
# Restoring model weights from the end of the best epoch.
#
# Epoch 00061: ReduceLROnPlateau reducing learning rate to 0.000800000037997961.
# 56/55 [==============================] - 85s 2s/step - loss: 0.0478 - accuracy: 0.9819 - val_loss: 0.1069 - val_accuracy: 0.9616 - lr: 0.0010
# Epoch 00061: early stopping
# Epoch 1/100
# 56/55 [==============================] - ETA: -1s - loss: 0.0744 - accuracy: 0.9746
# Epoch 00001: val_loss did not improve from 0.04016
# 56/55 [==============================] - 98s 2s/step - loss: 0.0744 - accuracy: 0.9746 - val_loss: 0.0484 - val_accuracy: 0.9774 - lr: 8.0000e-04
# Epoch 2/100
# 56/55 [==============================] - ETA: 0s - loss: 0.0628 - accuracy: 0.9757
# Epoch 00002: val_loss did not improve from 0.04016
# 56/55 [==============================] - 80s 1s/step - loss: 0.0628 - accuracy: 0.9757 - val_loss: 0.1008 - val_accuracy: 0.9571 - lr: 8.0000e-04
# Epoch 3/100
# 56/55 [==============================] - ETA: 0s - loss: 0.0547 - accuracy: 0.9780
# Epoch 00003: val_loss did not improve from 0.04016
# 56/55 [==============================] - 76s 1s/step - loss: 0.0547 - accuracy: 0.9780 - val_loss: 0.1197 - val_accuracy: 0.9526 - lr: 8.0000e-04
# Epoch 4/100
# 56/55 [==============================] - ETA: 0s - loss: 0.0758 - accuracy: 0.9746
# Epoch 00004: val_loss did not improve from 0.04016
# 56/55 [==============================] - 75s 1s/step - loss: 0.0758 - accuracy: 0.9746 - val_loss: 0.0645 - val_accuracy: 0.9752 - lr: 8.0000e-04
# Epoch 5/100
# 56/55 [==============================] - ETA: 0s - loss: 0.0504 - accuracy: 0.9785
# Epoch 00005: val_loss did not improve from 0.04016
# 56/55 [==============================] - 72s 1s/step - loss: 0.0504 - accuracy: 0.9785 - val_loss: 0.0710 - val_accuracy: 0.9752 - lr: 8.0000e-04
# Epoch 6/100
# 56/55 [==============================] - ETA: 0s - loss: 0.0606 - accuracy: 0.9780
# Epoch 00006: val_loss improved from 0.04016 to 0.03676, saving model to /modelcnd.h5
# 56/55 [==============================] - 82s 1s/step - loss: 0.0606 - accuracy: 0.9780 - val_loss: 0.0368 - val_accuracy: 0.9819 - lr: 8.0000e-04
# Epoch 7/100
# 56/55 [==============================] - ETA: 0s - loss: 0.0746 - accuracy: 0.9740
# Epoch 00007: val_loss did not improve from 0.03676
# 56/55 [==============================] - 79s 1s/step - loss: 0.0746 - accuracy: 0.9740 - val_loss: 0.0660 - val_accuracy: 0.9797 - lr: 8.0000e-04
# Epoch 8/100
# 56/55 [==============================] - ETA: 0s - loss: 0.0673 - accuracy: 0.9774
# Epoch 00008: val_loss did not improve from 0.03676
# 56/55 [==============================] - 75s 1s/step - loss: 0.0673 - accuracy: 0.9774 - val_loss: 0.0538 - val_accuracy: 0.9752 - lr: 8.0000e-04
# Epoch 9/100
# 56/55 [==============================] - ETA: 0s - loss: 0.0579 - accuracy: 0.9836
# Epoch 00009: val_loss did not improve from 0.03676
# 56/55 [==============================] - 73s 1s/step - loss: 0.0579 - accuracy: 0.9836 - val_loss: 0.0585 - val_accuracy: 0.9707 - lr: 8.0000e-04
# Epoch 10/100
# 56/55 [==============================] - ETA: 0s - loss: 0.0574 - accuracy: 0.9808
# Epoch 00010: val_loss did not improve from 0.03676
# 56/55 [==============================] - 73s 1s/step - loss: 0.0574 - accuracy: 0.9808 - val_loss: 0.0509 - val_accuracy: 0.9819 - lr: 8.0000e-04
# Epoch 11/100
# 56/55 [==============================] - ETA: 0s - loss: 0.0660 - accuracy: 0.9763
# Epoch 00011: val_loss did not improve from 0.03676
# 56/55 [==============================] - 74s 1s/step - loss: 0.0660 - accuracy: 0.9763 - val_loss: 0.0422 - val_accuracy: 0.9797 - lr: 8.0000e-04
# Epoch 12/100
# 56/55 [==============================] - ETA: 0s - loss: 0.0637 - accuracy: 0.9740
# Epoch 00012: val_loss did not improve from 0.03676
# 56/55 [==============================] - 73s 1s/step - loss: 0.0637 - accuracy: 0.9740 - val_loss: 0.0926 - val_accuracy: 0.9684 - lr: 8.0000e-04
# Epoch 13/100
# 56/55 [==============================] - ETA: 0s - loss: 0.0611 - accuracy: 0.9814
# Epoch 00013: val_loss did not improve from 0.03676
# 56/55 [==============================] - 74s 1s/step - loss: 0.0611 - accuracy: 0.9814 - val_loss: 0.0687 - val_accuracy: 0.9797 - lr: 8.0000e-04
# Epoch 14/100
# 56/55 [==============================] - ETA: 0s - loss: 0.0625 - accuracy: 0.9780
# Epoch 00014: val_loss did not improve from 0.03676
# 56/55 [==============================] - 78s 1s/step - loss: 0.0625 - accuracy: 0.9780 - val_loss: 0.0578 - val_accuracy: 0.9797 - lr: 8.0000e-04
# Epoch 15/100
# 56/55 [==============================] - ETA: 0s - loss: 0.0638 - accuracy: 0.9791
# Epoch 00015: val_loss did not improve from 0.03676
# 56/55 [==============================] - 86s 2s/step - loss: 0.0638 - accuracy: 0.9791 - val_loss: 0.0726 - val_accuracy: 0.9774 - lr: 8.0000e-04
# Epoch 16/100
# 56/55 [==============================] - ETA: 0s - loss: 0.0572 - accuracy: 0.9802
# Epoch 00016: val_loss did not improve from 0.03676
# 56/55 [==============================] - 113s 2s/step - loss: 0.0572 - accuracy: 0.9802 - val_loss: 0.0557 - val_accuracy: 0.9774 - lr: 8.0000e-04
# Epoch 17/100
# 56/55 [==============================] - ETA: 0s - loss: 0.0515 - accuracy: 0.9808
# Epoch 00017: val_loss did not improve from 0.03676
# 56/55 [==============================] - 85s 2s/step - loss: 0.0515 - accuracy: 0.9808 - val_loss: 0.0554 - val_accuracy: 0.9819 - lr: 8.0000e-04
# Epoch 18/100
# 56/55 [==============================] - ETA: 0s - loss: 0.0487 - accuracy: 0.9785
# Epoch 00018: val_loss did not improve from 0.03676
# 56/55 [==============================] - 85s 2s/step - loss: 0.0487 - accuracy: 0.9785 - val_loss: 0.0573 - val_accuracy: 0.9797 - lr: 8.0000e-04
# Epoch 19/100
# 56/55 [==============================] - ETA: 0s - loss: 0.0604 - accuracy: 0.9768
# Epoch 00019: val_loss did not improve from 0.03676
# 56/55 [==============================] - 92s 2s/step - loss: 0.0604 - accuracy: 0.9768 - val_loss: 0.0578 - val_accuracy: 0.9797 - lr: 8.0000e-04
# Epoch 20/100
# 56/55 [==============================] - ETA: 0s - loss: 0.0780 - accuracy: 0.9712
# Epoch 00020: val_loss did not improve from 0.03676
# 56/55 [==============================] - 87s 2s/step - loss: 0.0780 - accuracy: 0.9712 - val_loss: 0.0572 - val_accuracy: 0.9797 - lr: 8.0000e-04
# Epoch 21/100
# 56/55 [==============================] - ETA: 0s - loss: 0.0708 - accuracy: 0.9729
# Epoch 00021: val_loss did not improve from 0.03676
# 56/55 [==============================] - 79s 1s/step - loss: 0.0708 - accuracy: 0.9729 - val_loss: 0.0959 - val_accuracy: 0.9639 - lr: 8.0000e-04
# Epoch 22/100
# 56/55 [==============================] - ETA: 0s - loss: 0.0560 - accuracy: 0.9780
# Epoch 00022: val_loss did not improve from 0.03676
# 56/55 [==============================] - 77s 1s/step - loss: 0.0560 - accuracy: 0.9780 - val_loss: 0.0522 - val_accuracy: 0.9797 - lr: 8.0000e-04
# Epoch 23/100
# 56/55 [==============================] - ETA: 0s - loss: 0.0533 - accuracy: 0.9842
# Epoch 00023: val_loss did not improve from 0.03676
# 56/55 [==============================] - 80s 1s/step - loss: 0.0533 - accuracy: 0.9842 - val_loss: 0.1063 - val_accuracy: 0.9707 - lr: 8.0000e-04
# Epoch 24/100
# 56/55 [==============================] - ETA: 0s - loss: 0.0593 - accuracy: 0.9814
# Epoch 00024: val_loss did not improve from 0.03676
# 56/55 [==============================] - 83s 1s/step - loss: 0.0593 - accuracy: 0.9814 - val_loss: 0.0506 - val_accuracy: 0.9842 - lr: 8.0000e-04
# Epoch 25/100
# 56/55 [==============================] - ETA: 0s - loss: 0.0538 - accuracy: 0.9864
# Epoch 00025: val_loss did not improve from 0.03676
# 56/55 [==============================] - 84s 1s/step - loss: 0.0538 - accuracy: 0.9864 - val_loss: 0.0530 - val_accuracy: 0.9752 - lr: 8.0000e-04
# Epoch 26/100
# 56/55 [==============================] - ETA: 0s - loss: 0.0619 - accuracy: 0.9780
# Epoch 00026: val_loss did not improve from 0.03676
# 56/55 [==============================] - 79s 1s/step - loss: 0.0619 - accuracy: 0.9780 - val_loss: 0.0368 - val_accuracy: 0.9819 - lr: 8.0000e-04
# Epoch 27/100
# 56/55 [==============================] - ETA: 0s - loss: 0.0518 - accuracy: 0.9831
# Epoch 00027: val_loss did not improve from 0.03676
# 56/55 [==============================] - 78s 1s/step - loss: 0.0518 - accuracy: 0.9831 - val_loss: 0.0904 - val_accuracy: 0.9707 - lr: 8.0000e-04
# Epoch 28/100
# 56/55 [==============================] - ETA: 0s - loss: 0.0513 - accuracy: 0.9814
# Epoch 00028: val_loss did not improve from 0.03676
# 56/55 [==============================] - 75s 1s/step - loss: 0.0513 - accuracy: 0.9814 - val_loss: 0.0454 - val_accuracy: 0.9797 - lr: 8.0000e-04
# Epoch 29/100
# 56/55 [==============================] - ETA: 0s - loss: 0.0459 - accuracy: 0.9836
# Epoch 00029: val_loss did not improve from 0.03676
# 56/55 [==============================] - 76s 1s/step - loss: 0.0459 - accuracy: 0.9836 - val_loss: 0.0456 - val_accuracy: 0.9797 - lr: 8.0000e-04
# Epoch 30/100
# 56/55 [==============================] - ETA: 0s - loss: 0.0546 - accuracy: 0.9802
# Epoch 00030: val_loss did not improve from 0.03676
# 56/55 [==============================] - 78s 1s/step - loss: 0.0546 - accuracy: 0.9802 - val_loss: 0.0684 - val_accuracy: 0.9797 - lr: 8.0000e-04
# Epoch 31/100
# 56/55 [==============================] - ETA: 0s - loss: 0.0554 - accuracy: 0.9797
# Epoch 00031: val_loss did not improve from 0.03676
# 56/55 [==============================] - 74s 1s/step - loss: 0.0554 - accuracy: 0.9797 - val_loss: 0.0942 - val_accuracy: 0.9684 - lr: 8.0000e-04
# Epoch 32/100
# 56/55 [==============================] - ETA: 0s - loss: 0.0544 - accuracy: 0.9802
# Epoch 00032: val_loss did not improve from 0.03676
# 56/55 [==============================] - 75s 1s/step - loss: 0.0544 - accuracy: 0.9802 - val_loss: 0.0522 - val_accuracy: 0.9819 - lr: 8.0000e-04
# Epoch 33/100
# 56/55 [==============================] - ETA: 0s - loss: 0.0529 - accuracy: 0.9819
# Epoch 00033: val_loss did not improve from 0.03676
# 56/55 [==============================] - 77s 1s/step - loss: 0.0529 - accuracy: 0.9819 - val_loss: 0.0753 - val_accuracy: 0.9774 - lr: 8.0000e-04
# Epoch 34/100
# 56/55 [==============================] - ETA: 0s - loss: 0.0470 - accuracy: 0.9853
# Epoch 00034: val_loss did not improve from 0.03676
# 56/55 [==============================] - 85s 2s/step - loss: 0.0470 - accuracy: 0.9853 - val_loss: 0.0571 - val_accuracy: 0.9797 - lr: 8.0000e-04
# Epoch 35/100
# 56/55 [==============================] - ETA: 0s - loss: 0.0443 - accuracy: 0.9847
# Epoch 00035: val_loss did not improve from 0.03676
# 56/55 [==============================] - 78s 1s/step - loss: 0.0443 - accuracy: 0.9847 - val_loss: 0.0551 - val_accuracy: 0.9819 - lr: 8.0000e-04
# Epoch 36/100
# 56/55 [==============================] - ETA: 0s - loss: 0.0565 - accuracy: 0.9825
# Epoch 00036: val_loss did not improve from 0.03676
# Restoring model weights from the end of the best epoch.
#
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 0.0006400000303983689.
# 56/55 [==============================] - 78s 1s/step - loss: 0.0565 - accuracy: 0.9825 - val_loss: 0.0450 - val_accuracy: 0.9865 - lr: 8.0000e-04
# Epoch 00036: early stopping

# %% [markdown]
# # Testing

# %%
## Confusion matrix
plot_confusion_matrix(model, x_test, y_test)
## Learning curve
plot_learning_curves(history)
## ROC AUC
multiclass_roc_auc_score(x_test, y_test, model)
# Out:
# Confusion Matrix
# Precision Score: [0.97714286 0.98507463]
# Recall Score: [0.97714286 0.98507463]
# F1 Score: [0.97714286 0.98507463]
# Accuracy Score: 0.981941309255079
# AUC: 0.9811087420042643
# Log Loss: 0.036800326117698366

# %%
# saving model
model.save("modelcnd.h5")
